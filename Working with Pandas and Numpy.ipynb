# %%
import pandas as pd

# %%
df = pd.read_csv("updated_carbon_nanoptubes.csv")  #by-default consider 1st row in csv as col

# %%
df.head()
# Out:
#   Chiral indice n  Chiral indice m Initial atomic coordinate u  \
# 0               2              1.0                    0,679005
# 1               2              1.0                    0,717298
# 2               2              1.0                    0,489336
# 3               2              1.0                    0,413957
# 4               2              1.0                    0,334292
#
#   Initial atomic coordinate v Initial atomic coordinate w  \
# 0                    0,701318                    0,017033
# 1                    0,642129                    0,231319
# 2                    0,303751                    0,088462
# 3                    0,632996                    0,040843
# 4                    0,543401                     0,15989
#
#   Calculated atomic coordinates u' Calculated atomic coordinates v'  \
# 0                         0,721039                         0,730232
# 1                         0,738414                          0,65675
# ...

# %%
df = pd.read_csv("updated_carbon_nanoptubes.csv", header=None)   # if we dont want to consider 1st row as col then use header=None

# %%
type(df)     #dataframe --> datatype or structure of table
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()   # head show you top 5 records
# Out:
#                  0                1                            2  \
# 0  Chiral indice n  Chiral indice m  Initial atomic coordinate u
# 1                2                1                     0,679005
# 2                2                1                     0,717298
# 3                2                1                     0,489336
# 4                2                1                     0,413957
#
#                              3                            4  \
# 0  Initial atomic coordinate v  Initial atomic coordinate w
# 1                     0,701318                     0,017033
# 2                     0,642129                     0,231319
# 3                     0,303751                     0,088462
# 4                     0,632996                     0,040843
#
#                                   5                                 6  \
# 0  Calculated atomic coordinates u'  Calculated atomic coordinates v'
# ...

# %%
# if we want to rewrite col name then use names option 
pd.read_csv("updated_carbon_nanoptubes.csv", names=['chiral n', 'chiral m', 'cord u', 'cord v', 'cord w', 'cal cord u', 'cal cord v', 'cal cord w'])
# Out:
#                                                 chiral n         chiral m  \
# 0                                        Chiral indice n  Chiral indice m
# 1                                                      2                1
# 2                                                      2                1
# 3                                                      2                1
# 4                                                      2                1
# ...                                                  ...              ...
# 10721                                                 12                6
# 10722  2023-01-17 11:30:28,498 ERROR 'delimeter' is a...              NaN
# 10723  2023-01-17 11:31:14,942 ERROR 'delimeter' is a...              NaN
# 10724  2023-01-17 11:31:45,114 ERROR 'delimeter' is a...              NaN
# 10725  2023-01-17 11:32:06,061 ERROR 'delimeter' is a...              NaN
#
#                             cord u                       cord v  \
# ...

# %% [markdown]
# pd.read_csv("filename.csv",sep='seperator', skiprows=[row number separated by ,])

# %%
df.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# 7    object
# dtype: object

# %%
df.tail()
# Out:
#                                                        0    1         2  \
# 10721                                                 12    6  0,953664
# 10722  2023-01-17 11:30:28,498 ERROR 'delimeter' is a...  NaN       NaN
# 10723  2023-01-17 11:31:14,942 ERROR 'delimeter' is a...  NaN       NaN
# 10724  2023-01-17 11:31:45,114 ERROR 'delimeter' is a...  NaN       NaN
# 10725  2023-01-17 11:32:06,061 ERROR 'delimeter' is a...  NaN       NaN
#
#               3         4         5         6         7
# 10721  0,698374  0,962699  0,961243  0,707812  0,962605
# 10722       NaN       NaN       NaN       NaN       NaN
# 10723       NaN       NaN       NaN       NaN       NaN
# 10724       NaN       NaN       NaN       NaN       NaN
# 10725       NaN       NaN       NaN       NaN       NaN

# %%
df.columns
# Out:
# Index(['Chiral indice n', 'Chiral indice m', 'Initial atomic coordinate u',
#        'Initial atomic coordinate v', 'Initial atomic coordinate w',
#        'Calculated atomic coordinates u'', 'Calculated atomic coordinates v'',
#        'Calculated atomic coordinates w''],
#       dtype='object')

# %%
a = df['Chiral indice n']  # extract data from single col

# %%
a
# Out:
# 0                                                        2
# 1                                                        2
# 2                                                        2
# 3                                                        2
# 4                                                        2
#                                ...
# 10720                                                   12
# 10721    2023-01-17 11:30:28,498 ERROR 'delimeter' is a...
# 10722    2023-01-17 11:31:14,942 ERROR 'delimeter' is a...
# 10723    2023-01-17 11:31:45,114 ERROR 'delimeter' is a...
# 10724    2023-01-17 11:32:06,061 ERROR 'delimeter' is a...
# Name: Chiral indice n, Length: 10725, dtype: object

# %%
type(a)   # series is nothing but a list of data i.e when single col is extracted from dataframe(collection of series)
# Out:
# pandas.core.series.Series

# %%
b = df[['Chiral indice n','Chiral indice m']]

# %%
b
# Out:
#                                          Chiral indice n  Chiral indice m
# 0                                                      2              1.0
# 1                                                      2              1.0
# 2                                                      2              1.0
# 3                                                      2              1.0
# 4                                                      2              1.0
# ...                                                  ...              ...
# 10720                                                 12              6.0
# 10721  2023-01-17 11:30:28,498 ERROR 'delimeter' is a...              NaN
# 10722  2023-01-17 11:31:14,942 ERROR 'delimeter' is a...              NaN
# 10723  2023-01-17 11:31:45,114 ERROR 'delimeter' is a...              NaN
# 10724  2023-01-17 11:32:06,061 ERROR 'delimeter' is a...              NaN
#
# [10725 rows x 2 columns]

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
a = df[['Chiral indice n']] #when we pass single col as list it is a dataframe. if we pass single col without list it will be series

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.read_excel('Options_data.xlsm')  # by default open first sheet
# Out:
#    Unnamed: 0                                         Unnamed: 1
# 0         NaN                                           Coockies
# 1         NaN  nsit=SZ-CKB3iOXmAxb9fZnQOVAid; AKA_A2=A; ak_bm...

# %%
pd.read_excel('Options_data.xlsm',sheet_name='Data')
# Out:
#     strikePrice   expiryDate  CE.openInterest  CE.underlyingValue  \
# 0         14350  24-Mar-2022               18             17315.5
# 1         14400  24-Mar-2022                1             17315.5
# 2         14450  24-Mar-2022                1             17315.5
# 3         14500  24-Mar-2022                2             17315.5
# 4         14550  24-Mar-2022                0             17315.5
# ..          ...          ...              ...                 ...
# 95        19100  24-Mar-2022             4459             17315.5
# 96        19150  24-Mar-2022             1338             17315.5
# 97        19200  24-Mar-2022             6309             17315.5
# 98        19250  24-Mar-2022              506             17315.5
# 99        19300  24-Mar-2022            47092             17315.5
#
#     PE.openInterest  PE.underlyingValue
# 0             11919             17315.5
# 1              9672             17315.5
# 2               240             17315.5
# ...

# %%
#if we have to check what ,any sheets are available in excel 
list = pd.ExcelFile('Options_data.xlsm')

# %%
list.sheet_names
# Out:
# ['Sheet1', 'Data', 'Chart', 'Sheet6']

# %%
for i in list.sheet_names:
    print(pd.read_excel('Options_data.xlsm', sheet_name=i))
# Out:
#    Unnamed: 0                                         Unnamed: 1
# 0         NaN                                           Coockies
# 1         NaN  nsit=SZ-CKB3iOXmAxb9fZnQOVAid; AKA_A2=A; ak_bm...
#     strikePrice   expiryDate  CE.openInterest  CE.underlyingValue  \
# 0         14350  24-Mar-2022               18             17315.5
# 1         14400  24-Mar-2022                1             17315.5
# 2         14450  24-Mar-2022                1             17315.5
# 3         14500  24-Mar-2022                2             17315.5
# 4         14550  24-Mar-2022                0             17315.5
# ..          ...          ...              ...                 ...
# 95        19100  24-Mar-2022             4459             17315.5
# 96        19150  24-Mar-2022             1338             17315.5
# 97        19200  24-Mar-2022             6309             17315.5
# 98        19250  24-Mar-2022              506             17315.5
# ...

# %%
#read csv from git
pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv')
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...
